# %%
from pykalman import KalmanFilter
import numpy as np
import pandas as pd
import sys
import matplotlib
import matplotlib.pyplot as plt
from skimage.color import lab2rgb
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import skimage
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from functools import reduce
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
from scipy import stats

# %%
wikidata = pd.read_json('movies/data/wikidata-movies.json.gz', orient='record', lines=True, encoding="utf8")
genres = pd.read_json('movies/data/genres.json.gz', orient='record', lines=True, encoding="utf8")

# %%
movies = wikidata[wikidata['made_profit'].notnull()]
#movies = wikidata

# %%
def map_genre(row):
    result = []
    for genre_code in row['genre']:
        matches = genres[genres['wikidata_id'] == genre_code]['genre_label'].values
        for match in matches:
            result.append(match)
    return result

# %%
movies = movies.copy() #from https://stackoverflow.com/questions/31468176/setting-values-on-a-copy-of-a-slice-from-a-dataframe?rq=1
movies['genre_names'] = movies.apply(map_genre,axis=1)

# %%
#movies

# %%
rotten_tomatoes = pd.read_json('movies/data/rotten-tomatoes.json.gz', orient='record', lines=True)

# %%
#rotten_tomatoes

# %%
omdb = pd.read_json('movies/data/omdb-data.json.gz', orient='record', lines=True)

# %%
#omdb

# %%
combined = movies.join(rotten_tomatoes.set_index('rotten_tomatoes_id'), on='rotten_tomatoes_id', rsuffix='_rt')

# %%
combined = combined.join(omdb.set_index('imdb_id'), on='imdb_id')

# %%
combined
# Out:
#         based_on                                        cast_member  \
# 6            NaN            [Q5126010, Q3390414, Q5676024, Q237021]
# 69           NaN                                                NaN
# 73           NaN  [Q386349, Q1605965, Q3805579, Q271162, Q463226...
# 81     Q17017426  [Q117500, Q1376880, Q11930, Q311169, Q951634, ...
# 84           NaN  [Q38111, Q211553, Q177311, Q8927, Q173399, Q20...
# 92           NaN  [Q229313, Q445772, Q727988, Q3163137, Q1372392...
# 113      Q243556  [Q34012, Q41163, Q95043, Q464714, Q171736, Q32...
# 125          NaN  [Q483118, Q23547, Q108283, Q215072, Q270664, Q...
# 203     Q7857661  [Q317343, Q57147, Q244674, Q343616, Q208649, Q...
# 483          NaN  [Q295803, Q200534, Q228865, Q200405, Q314133, ...
# 643          NaN                               [Q2376200, Q2299195]
# 879       Q40354  [Q189490, Q217004, Q32045, Q201279, Q219373, Q...
# 917          NaN                               [Q4271506, Q4333656]
# 947          NaN  [Q4495971, Q1074254, Q4079472, Q18008969, Q410...
# 1393         NaN            [Q3479732, Q1074254, Q4273944, Q777625]
# 2023    Q2545790  [Q503706, Q44158, Q190162, Q525065, Q355168, Q...
# 2096         NaN                                                NaN
# 3663    Q8065468                                                NaN
# 4334         NaN  [Q264840, Q351290, Q528126, Q233502, Q94913, Q...
# 5226         NaN           [Q193517, Q313039, Q29809869, Q38410137]
# 5915      Q83279  [Q299282, Q591238, Q4337, Q4488, Q454102, Q415...
# 6167         NaN             [Q442830, Q3479732, Q1966992, Q282818]
# 6788         NaN  [Q299317, Q1336685, Q3308078, Q360477, Q313545...
# 6916    Q2944381  [Q873, Q40523, Q165518, Q201418, Q294583, Q273...
# 6930     Q140527  [Q544641, Q183535, Q3553607, Q2119044, Q415100...
# 39586                                     22 Jump Street
# 39604                                  Paddington (film)
# 39628                                    Warcraft (film)
# 39680                                  Annie (2014 film)
# 39718  Alexander and the Terrible, Horrible, No Good,...
# 39729                                     Chappie (film)
# 39737                                      Love in Vegas
# 39750                             Penguins of Madagascar
# 39752                                          Self/less
# 39755                                Everest (2015 film)
# 39776                                   John Wick (film)
# 39777                                   Annabelle (film)
# 39828                         How to Train Your Dragon 2
# 39957                                    American Hustle
# 40040                                        Legend № 17
# 40133                     Ghost in the Shell (2017 film)
# 40166          Three Billboards Outside Ebbing, Missouri
# 40280                                Interstellar (film)
# 40323                             The Signal (2014 film)
# 40353                                   Life (2017 film)
# 40357                                 The Shape of Water
# 40360                             Earthquake (2016 film)
# 40373                                I Am Not Your Negro
#
#                                         filming_location  \
# 6                                                    NaN
# 69                                                   NaN
# 73                                                 [Q99]
# 81                                               [Q1558]
# 84     [Q99, Q387047, Q17, Q90, Q1951, Q7275217, Q126...
# 92                               [Q172, Q133116, Q13939]
# 113                          [Q18438, Q60, Q1408, Q1460]
# 125                                     [Q406, Q65, Q43]
# 203                                             [Q34404]
# 483                                         [Q183, Q365]
# 643                                              [Q2280]
# 879                            [Q23556, Q64, Q90, Q1428]
# 917                                                  NaN
# 947                                                  NaN
# 1393                                                 NaN
# 2023                   [Q84, Q2278256, Q6673670, Q44057]
# 2096                                                 NaN
# 3663                                                 NaN
# 4334                                             [Q1454]
# 5226                                                 NaN
# 5915                                             [Q1428]
# 6167                                                 NaN
# 6788                                                 NaN
# 6916                                                 NaN
# 6930                                                 NaN
# 6955                                [Q408, Q869, Q23436]
# 6992                                                 NaN
# 7001                                                 NaN
# 7440                                         [Q64, Q183]
# 8406                                                 NaN
# ...                                                  ...
# 39373                                                NaN
# 39374                                                NaN
# 39383                                                NaN
# 39388                              [Q1522, Q1588, Q1494]
# 39467                                                NaN
# 39531                        [Q65, Q23556, Q1261, Q1519]
# 39571                                              [Q60]
# 39586                                           [Q34404]
# 39604                                              [Q84]
# 39628                                           [Q24639]
# 39680                                              [Q60]
# 39718                                              [Q65]
# 39729                                 [Q1812844, Q34647]
# 39737                                                NaN
# 39750                                                NaN
# 39752                                      [Q34404, Q60]
# 39755        [Q3037, Q1043277, Q837, Q38, Q145, Q661896]
# 39776                                              [Q60]
# 39777                                              [Q65]
# 39828                                                NaN
# 39957                                              [Q60]
# 40040                                 [Q863096, Q207294]
# 40133                                           [Q23661]
# 40166                                         [Q2043861]
# 40280                                 [Q189, Q65, Q1951]
# 40323                                            [Q1522]
# 40353                                                NaN
# 40357                                          [Q133116]
# 40360                                                NaN
# 40373                                                NaN
#
#                                                    genre    imdb_id  \
# 6                                    [Q24925, Q21010853]  tt3469798
# 69                                             [Q157443]  tt1323594
# 73                          [Q130232, Q200092, Q5967378]  tt0074486
# 81     [Q130232, Q369747, Q21590660, Q21010853, Q319221]  tt0099348
# 84        [Q496523, Q471839, Q2484376, Q188473, Q319221]  tt1375666
# 92                                             [Q200092]  tt2023587
# 40357             [Q2973181, Q191489, Q2484376, Q157394]  tt5580390
# 40360                      [Q130232, Q846544, Q21010853]  tt5270810
# 40373                                           [Q93204]  tt5804038
#
#                                                    label  made_profit  \
# 6                                              Orbiter 9          0.0
# 69                                         Despicable Me          1.0
# 73                                            Eraserhead          1.0
# 81                                    Dances with Wolves          1.0
# 84                                             Inception          1.0
# 92                                                  Mama          1.0
# 113                                        The Godfather          1.0
# 125                                                 Argo          1.0
# 203                                     12 Years a Slave          1.0
# 483                               Only Lovers Left Alive          1.0
# 643                                        The PyraMMMid          1.0
# 879                The Hunger Games: Mockingjay – Part 1          1.0
# 917                                    Inadequate people          1.0
# 947                                     The Best Movie 2          1.0
# 1393                       Our Russia. The Balls of Fate          1.0
# 2023                             Guardians of the Galaxy          1.0
# 2096                                          Inside Out          1.0
# 3663                                           Pinocchio          1.0
# 4334                                       The Conjuring          1.0
# 5226                                       A Quiet Place          1.0
# 5915            The SpongeBob Movie: Sponge Out of Water          1.0
# 6167                                             Yolki 2          1.0
# 6788                  Butch and Sundance: The Early Days          0.0
# 6916                                August: Osage County          1.0
# 6930   The Return of the Musketeers, or The Treasures...          0.0
# 6955                                     The Railway Man          0.0
# 6992                                         Moscow Heat          0.0
# 7001                                 What Men Talk About          1.0
# 7440                                       Monuments Men          1.0
# 8406                                          About Time          1.0
# ...                                                  ...          ...
# 39373                        Kingsman: The Golden Circle          1.0
# 39374                             Avengers: Infinity War          1.0
# 39383                                    The Emoji Movie          1.0
# 39388                                              Logan          1.0
# 39467                                         Big Hero 6          1.0
# 39531                                          Furious 7          1.0
# 39571                          This Is Where I Leave You          1.0
# 39586                                     22 Jump Street          1.0
# 39604                                         Paddington          1.0
# 39628                                           Warcraft          1.0
# 39680                                              Annie          1.0
# 39718  Alexander and the Terrible, Horrible, No Good,...          1.0
# 39729                                            Chappie          1.0
# 39737                                                NaN          1.0
# 39750                             Penguins of Madagascar          1.0
# 39752                                          Self/less          1.0
# 39755                                            Everest          1.0
# 39776                                          John Wick          1.0
# 39777                                          Annabelle          1.0
# 39828                         How to Train Your Dragon 2          1.0
# 39957                                    American Hustle          1.0
# 40040                                     Legenda No. 17          1.0
# 40133                                 Ghost in the Shell          1.0
# 40166          Three Billboards Outside Ebbing, Missouri          1.0
# 40280                                       Interstellar          1.0
# 40323                                         The Signal          0.0
# 40353                                               Life          1.0
# 40357                                 The Shape of Water          1.0
# 40360                                         Earthquake          0.0
# 40373                                I Am Not Your Negro          1.0
#
#                              ...                          \
# 6                            ...
# 69                           ...
# 73                           ...
# 81                           ...
# 84                           ...
# 92                           ...
# 113                          ...
# 125                          ...
# 203                          ...
# 483                          ...
# 643                          ...
# 879                          ...
# 917                          ...
# 947                          ...
# 1393                         ...
# 2023                         ...
# 2096                         ...
# 3663                         ...
# 4334                         ...
# 5226                         ...
# 5915                         ...
# 6167                         ...
# 6788                         ...
# 6916                         ...
# 6930                         ...
# 6955                         ...
# 6992                         ...
# 7001                         ...
# 7440                         ...
# 8406                         ...
# 40353  tt5442430                                     5 nominations.
# 40357  tt5580390  Won 4 Oscars. Another 101 wins & 293 nominations.
# 40360  tt5270810                                                N/A
# 40373  tt5804038  Nominated for 1 Oscar. Another 25 wins & 45 no...
#
#                           omdb_genres  \
# 6            [Drama, Romance, Sci-Fi]
# 69     [Animation, Adventure, Comedy]
# 73                           [Horror]
# 81        [Adventure, Drama, Western]
# 84        [Action, Adventure, Sci-Fi]
# 92                 [Horror, Thriller]
# 113                    [Crime, Drama]
# 125      [Biography, Drama, Thriller]
# 203       [Biography, Drama, History]
# 483          [Comedy, Drama, Fantasy]
# 643                    [Crime, Drama]
# 879       [Action, Adventure, Sci-Fi]
# 917          [Comedy, Drama, Romance]
# 947                          [Comedy]
# 1393                         [Comedy]
# 2023      [Action, Adventure, Sci-Fi]
# 2096   [Animation, Adventure, Comedy]
# 3663      [Animation, Comedy, Family]
# 4334      [Horror, Mystery, Thriller]
# 5226          [Drama, Horror, Sci-Fi]
# 5915   [Animation, Adventure, Comedy]
# 6167                         [Comedy]
# 6788                [Comedy, Western]
# 6916                          [Drama]
# 6930      [Action, Adventure, Comedy]
# 6955      [Biography, Drama, Romance]
# 6992                  [Action, Drama]
# 7001                         [Comedy]
# 7440            [Drama, History, War]
# 8406         [Comedy, Drama, Fantasy]
# ...                               ...
# 39373     [Action, Adventure, Comedy]
# 39374    [Action, Adventure, Fantasy]
# 39383  [Animation, Adventure, Comedy]
# 39388         [Action, Drama, Sci-Fi]
# 39467  [Animation, Action, Adventure]
# 39531       [Action, Crime, Thriller]
# 39571                 [Comedy, Drama]
# 39586         [Action, Comedy, Crime]
# 39604  [Animation, Adventure, Comedy]
# 39628    [Action, Adventure, Fantasy]
# 39680         [Comedy, Drama, Family]
# 39718                [Comedy, Family]
# 39729          [Action, Crime, Drama]
# 39737               [Comedy, Fantasy]
# 39750  [Animation, Adventure, Comedy]
# 39752       [Action, Mystery, Sci-Fi]
# 39755  [Action, Adventure, Biography]
# 39776       [Action, Crime, Thriller]
# 39777     [Horror, Mystery, Thriller]
# 39828  [Animation, Action, Adventure]
# 39957                  [Crime, Drama]
# 40040       [Biography, Drama, Sport]
# 40133          [Action, Crime, Drama]
# 40166                  [Crime, Drama]
# 40280      [Adventure, Drama, Sci-Fi]
# 40323              [Sci-Fi, Thriller]
# 40353      [Horror, Sci-Fi, Thriller]
# 40357     [Adventure, Drama, Fantasy]
# 40360                         [Drama]
# 40373                   [Documentary]
#
#                                                omdb_plot
# 6      Helena is a young girl who spent all her life ...
# 69     In a happy suburban neighborhood surrounded by...
# 73     A film that defies conventional logic and stor...
# 81     Lt. John Dunbar is dubbed a hero after he acci...
# 84     Dom Cobb is a skilled thief, the absolute best...
# 92     The senior partner of an investment brokerage,...
# 113    When the aging head of a famous crime family d...
# 125    In 1979, the American embassy in Iran was inva...
# 203    Based on an incredible true story of one man's...
# 483    Adam (Tom Hiddleston), an underground musician...
# 643    Russia, early 90s. A fictional story inspired ...
# 879    With the Games destroyed, Katniss Everdeen, al...
# 917    Adequacy is relative. Vitalik, the main charac...
# 947    Four friends after a long separation are celeb...
# 1393                                                 N/A
# 2023   After stealing a mysterious orb in the far rea...
# 2096   Growing up can be a bumpy road, and it's no ex...
# 3663   Inventor Gepetto creates a wooden marionette c...
# 4334   In 1971, Carolyn and Roger Perron move their f...
# 5226   In a post-apocalyptic world, a family is force...
# 5915   During a fight between the Krusty Krab and Pla...
# 6167   Film is a collection of several interlinked st...
# 6788   A prequel of sorts to Butch Cassidy and the Su...
# 6916   Violet Weston (Meryl Streep) has cancer and a ...
# 6930   After the deaths of d'Artagnan, Athos, Porthos...
# 6955   Eric Lomax was one of thousands of Allied pris...
# 6992   A retired Diplomat and an NYPD Detective seeki...
# 7001   The plot revolves around four old friends-Kami...
# 7440   Based on the true story of the greatest treasu...
# 8406   At the age of 21, Tim Lake (Domhnall Gleeson) ...
# ...                                                  ...
# 39373  When the Kingsman headquarters are destroyed a...
# 39374  The Avengers and their allies must be willing ...
# 39383  The Emoji Movie unlocks the never-before-seen ...
# 39388  In 2029 the mutant population has shrunken sig...
# 39467  When a devastating event befalls the city of S...
# 39531  Dominic and his crew thought they'd left the c...
# 39571  When their father passes away, four grown sibl...
# 39586  After making their way through high school (tw...
# 39604  A young Peruvian bear with a passion for all t...
# 39628  When the world of the Orcs of Draenor is being...
# 39680  Annie is a young, happy foster kid who's also ...
# 39718  For 12 year old Alexander Cooper, everyday is ...
# 39729  In Johannesburg, the police department reduced...
# 39737  There comes a time when wife leaves for a dese...
# 39750  Super spy teams aren't born...they're hatched....
# 39752  An extremely wealthy man, dying from cancer, u...
# 39755  On the morning of May 10, 1996, climbers from ...
# 39776  An ex-hitman comes out of retirement to track ...
# 39777  John Form has found the perfect gift for his e...
# 39828  It's been five years since Hiccup and Toothles...
# 39957  A fictional film set in the alluring world of ...
# 40040  Biopic of Russian ice hockey legend Valeri Kha...
# 40133  In the near future, Major Motoko Kusanagi (Sca...
# 40166  THREE BILLBOARDS OUTSIDE EBBING, MISSOURI is a...
# 40280  Earth's future has been riddled by disasters, ...
# 40323  On a road trip, Nic and two friends are drawn ...
# 40353  Six astronauts aboard the space station study ...
# 40357  At a top secret research facility in the 1960s...
# 40360  Leninakan, Armenian SSR, USSR, 1988. After the...
# 40373  In 1979, James Baldwin wrote a letter to his l...
#
# [791 rows x 27 columns]

# %%
# plt.title('Popularity Distribution')
# plt.xlabel('Rank')
# plt.ylabel('Views')
plt.scatter(combined['critic_average'], combined['audience_average'])

# %%
test3 = combined[combined['audience_average'].notnull() & combined['critic_average'].notnull()]
print(stats.normaltest(test3['audience_average']).pvalue) #<0.05, therefore not normal
print(stats.mannwhitneyu(test3['critic_average'], test3['audience_average']).pvalue) #>0.05, therefore means differ
# Out:
# 0.0012723373652919845
# 3.3258184811768664e-205

# %%
chi2, p, dof, expected = stats.chi2_contingency([test3['critic_average'].values, test3['audience_average'].values])
print(p) #>0.05, therefore one has no effect on the other?
print(expected)
# Out:
# 1.0
# [[5.5546799  7.87989474 7.16941243 ... 5.9422157  7.87989474 8.39660915]
#  [3.0453201  4.32010526 3.93058757 ... 3.2577843  4.32010526 4.60339085]]

# %%
# chi2, p, dof, expected = stats.chi2_contingency([test3['critic_average'].values, test3['genre'].values])
# print(p) #>0.05, therefore one has no effect on the other?
# print(expected)

# %%
#combined.groupby('genre_names')
#pd.value_counts(combined.groupby('genre_names'), sort=False)
## TODO: Count distrbution of genres and graph on histogram
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-89ff50c2c104> in <module>()
#       1 #combined.groupby('genre_names')
# ----> 2 pd.value_counts(combined.groupby('genre_names'), sort=False)
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     714
#     715         else:
# --> 716             keys, counts = _value_counts_arraylike(values, dropna)
#     717
#     718             if not isinstance(keys, Index):
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in _value_counts_arraylike(values, dropna)
#     741
#     742     """
# --> 743     values = _ensure_arraylike(values)
#     744     original = values
#     745     values, dtype, ndtype = _ensure_data(values)
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in _ensure_arraylike(values)
#     175     """
#     176     if not is_array_like(values):
# --> 177         inferred = lib.infer_dtype(values)
#     178         if inferred in ['mixed', 'string', 'unicode']:
#     179             if isinstance(values, tuple):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.infer_dtype()
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in get_iterator(self, data, axis)
#    2224         for each group
#    2225         """
# -> 2226         splitter = self._get_splitter(data, axis=axis)
#    2227         keys = self._get_group_keys()
#    2228         for key, (i, group) in zip(keys, splitter):
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_splitter(self, data, axis)
#    2230
#    2231     def _get_splitter(self, data, axis=0):
# -> 2232         comp_ids, _, ngroups = self.group_info
#    2233         return get_splitter(data, comp_ids, ngroups, axis=axis)
#    2234
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in group_info(self)
#    2333     @cache_readonly
#    2334     def group_info(self):
# -> 2335         comp_ids, obs_group_ids = self._get_compressed_labels()
#    2336
#    2337         ngroups = len(obs_group_ids)
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_compressed_labels(self)
#    2349
#    2350     def _get_compressed_labels(self):
# -> 2351         all_labels = [ping.labels for ping in self.groupings]
#    2352         if len(all_labels) > 1:
#    2353             group_index = get_group_index(all_labels, self.shape,
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <listcomp>(.0)
#    2349
#    2350     def _get_compressed_labels(self):
# -> 2351         all_labels = [ping.labels for ping in self.groupings]
#    2352         if len(all_labels) > 1:
#    2353             group_index = get_group_index(all_labels, self.shape,
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in labels(self)
#    3068     def labels(self):
#    3069         if self._labels is None:
# -> 3070             self._make_labels()
#    3071         return self._labels
#    3072
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_labels(self)
#    3101             else:
#    3102                 labels, uniques = algorithms.factorize(
# -> 3103                     self.grouper, sort=self.sort)
#    3104                 uniques = Index(uniques, name=self.name)
#    3105             self._labels = labels
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     628                                            na_sentinel=na_sentinel,
#     629                                            size_hint=size_hint,
# --> 630                                            na_value=na_value)
#     631
#     632     if sort and len(uniques) > 0:
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     474     uniques = vec_klass()
#     475     labels = table.get_labels(values, uniques, 0, na_sentinel,
# --> 476                               na_value=na_value)
#     477
#     478     labels = _ensure_platform_int(labels)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# TypeError: unhashable type: 'list'
